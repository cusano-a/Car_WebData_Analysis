# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
from datetime import datetime
from dotenv import load_dotenv
import regex as re

from comet_ml import Experiment
from sklearn.compose import make_column_transformer, TransformedTargetRegressor
from sklearn.feature_extraction import FeatureHasher
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn import set_config
import joblib
from xgboost import XGBRegressor

# %%
# %matplotlib inline
sns.set_theme()
set_config(display='diagram')
data_path = os.path.join("..", "data", "usedcars_dataset.csv")

# %% [markdown]
# ## Loading Model

# %%
def load_usedcars_data(data_path):
    df = pd.read_csv(data_path, sep=";", index_col="url")
    df = (df.astype({'Anno':'datetime64[ns]', 'date':'datetime64[ns]'})
        .assign(age_years= lambda x: (x['date'] - x['Anno']) / np.timedelta64(1, 'Y'))
        .dropna(subset=['price', 'potenza_kw', 'age_years', 'Chilometraggio'])
        .drop(columns=['Extra', 'Comfort', 'Sicurezza'])
        )
    return df

def filter_usedcars_data(df, max_price=1e6, min_price=100, max_age=40, max_cv=1000, max_km=1e6, max_engsize=1e4):
    df = df.query("~((age_years>@max_age or age_years < 0) \
                                or (potenza_cv > @max_cv or potenza_cv < 0) \
                                or (Chilometraggio>@max_km or Chilometraggio < 0) \
                                or (price > @max_price or price < @min_price ) \
                                or (Cilindrata_cm3 > @max_engsize or Cilindrata_cm3 < 0 ) \
                    )"
                )
    return df

# %%
df = load_usedcars_data(data_path)
df = filter_usedcars_data(df)

# %%
df_train, df_test = train_test_split(df, test_size=0.1)
X_train = df_train.drop(columns=['price'])
y_train = df_train['price']
X_test = df_test.drop(columns=['price'])
y_test = df_test['price']

# %% [markdown]
# ## Building Pipeline

# %%
numerical_columns = ['Chilometraggio',
                    'Cilindrata_cm3',
                    'Cilindri',
                    'Consumo_comb_L100km',
                    'Marce',
                    'Peso_a_vuoto_kg',
                    'Porte',
                    'Posti',
                    'age_years',
                    'potenza_cv'
                ]

categorical_ohe_columns = ['Carburante',
                            'Carrozzeria',
                            'Tipo_di_cambio',
                            'Tipo_di_veicolo',
                            'Trazione'
                        ]
                        
categorical_fh_columns = ['maker', 'model']

# %%
#Numerical features pipeline
num_transformer = make_pipeline(
    SimpleImputer(strategy='median'),
    StandardScaler(),
    memory = 'cache'
)

#Categorical OneHotEncoding features pipeline
cat_transformer = make_pipeline(
    SimpleImputer(strategy='most_frequent'),
    OneHotEncoder(handle_unknown='ignore'),
    memory = 'cache'
)

#Catgeorical Hashed features pipeline
hash_transformer_maker = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='Altro'),
    FeatureHasher(n_features=2**8, input_type='string'),
    memory = 'cache'
)

#Catgeorical Hashed features pipeline
hash_transformer_model = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='Altro'),
    FeatureHasher(n_features=2**11, input_type='string'),
    memory = 'cache'
)

# Preprocessing pipeline
preprocessor = make_column_transformer(
    (num_transformer, numerical_columns),
    (cat_transformer, categorical_ohe_columns),
    (hash_transformer_maker, ['maker']),
    (hash_transformer_model, ['model']),
    remainder = 'drop'
)

# %%
regressor_pipe = make_pipeline(
    preprocessor,
    XGBRegressor(
        objective='reg:absoluteerror'
        ),
    memory = 'cache'
    )

global_pipe = make_pipeline(
    TransformedTargetRegressor(
        regressor=regressor_pipe,
        func=np.log,
        inverse_func=np.exp
    ),
    memory = 'cache'
)

# %%
global_pipe.get_params()
# Out:
# {'memory': 'cache',
#  'steps': [('transformedtargetregressor',
#    TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                               regressor=Pipeline(memory='cache',
#                                                  steps=[('columntransformer',
#                                                          ColumnTransformer(transformers=[('pipeline-1',
#                                                                                           Pipeline(memory='cache',
#                                                                                                    steps=[('simpleimputer',
#                                                                                                            SimpleImputer(strategy='median')),
#                                                                                                           ('standardscaler',
#                                                                                                            StandardScaler())]),
#                                                                                           ['Chilometraggio',
#                                                                                            'Cilindrata_cm3',
#                                                                                            'Cilindri',
#                                                                                            'Cons...
#                                                                       grow_policy=None,
#                                                                       importance_type=None,
#                                                                       interaction_constraints=None,
#                                                                       learning_rate=None,
#                                                                       max_bin=None,
#                                                                       max_cat_threshold=None,
#                                                                       max_cat_to_onehot=None,
#                                                                       max_delta_step=None,
#                                                                       max_depth=None,
#                                                                       max_leaves=None,
#                                                                       min_child_weight=None,
#                                                                       missing=nan,
#                                                                       monotone_constraints=None,
#                                                                       n_estimators=100,
#                                                                       n_jobs=None,
#                                                                       num_parallel_tree=None,
#                                                                       objective='reg:absoluteerror',
#                                                                       predictor=None, ...))])))],
#  'verbose': False,
#  'transformedtargetregressor': TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                             regressor=Pipeline(memory='cache',
#                                                steps=[('columntransformer',
#                                                        ColumnTransformer(transformers=[('pipeline-1',
#                                                                                         Pipeline(memory='cache',
#                                                                                                  steps=[('simpleimputer',
#                                                                                                          SimpleImputer(strategy='median')),
#                                                                                                         ('standardscaler',
#                                                                                                          StandardScaler())]),
#                                                                                         ['Chilometraggio',
#                                                                                          'Cilindrata_cm3',
#                                                                                          'Cilindri',
#                                                                                          'Cons...
#                                                                     grow_policy=None,
#                                                                     importance_type=None,
#                                                                     interaction_constraints=None,
#                                                                     learning_rate=None,
#                                                                     max_bin=None,
#                                                                     max_cat_threshold=None,
#                                                                     max_cat_to_onehot=None,
#                                                                     max_delta_step=None,
#                                                                     max_depth=None,
#                                                                     max_leaves=None,
#                                                                     min_child_weight=None,
#                                                                     missing=nan,
#                                                                     monotone_constraints=None,
#                                                                     n_estimators=100,
#                                                                     n_jobs=None,
#                                                                     num_parallel_tree=None,
#                                                                     objective='reg:absoluteerror',
#                                                                     predictor=None, ...))])),
#  'transformedtargetregressor__check_inverse': True,
#  'transformedtargetregressor__func': <ufunc 'log'>,
#  'transformedtargetregressor__inverse_func': <ufunc 'exp'>,
#  'transformedtargetregressor__regressor__memory': 'cache',
#  'transformedtargetregressor__regressor__steps': [('columntransformer',
#    ColumnTransformer(transformers=[('pipeline-1',
#                                     Pipeline(memory='cache',
#                                              steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     ['Chilometraggio', 'Cilindrata_cm3',
#                                      'Cilindri', 'Consumo_comb_L100km', 'Marce',
#                                      'Peso_a_vuoto_kg', 'Porte', 'Posti',
#                                      'age_years', 'potenza_cv']),
#                                    ('pipeline-2',
#                                     Pipeline(memory='cache',
#                                              steps=[('...
#                                              steps=[('simpleimputer',
#                                                      SimpleImputer(fill_value='Altro',
#                                                                    strategy='constant')),
#                                                     ('featurehasher',
#                                                      FeatureHasher(input_type='string',
#                                                                    n_features=256))]),
#                                     ['maker']),
#                                    ('pipeline-4',
#                                     Pipeline(memory='cache',
#                                              steps=[('simpleimputer',
#                                                      SimpleImputer(fill_value='Altro',
#                                                                    strategy='constant')),
#                                                     ('featurehasher',
#                                                      FeatureHasher(input_type='string',
#                                                                    n_features=2048))]),
#                                     ['model'])])),
#   ('xgbregressor',
#    XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='reg:absoluteerror', predictor=None, ...))],
#  'transformedtargetregressor__regressor__verbose': False,
#  'transformedtargetregressor__regressor__columntransformer': ColumnTransformer(transformers=[('pipeline-1',
#                                   Pipeline(memory='cache',
#                                            steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   ['Chilometraggio', 'Cilindrata_cm3',
#                                    'Cilindri', 'Consumo_comb_L100km', 'Marce',
#                                    'Peso_a_vuoto_kg', 'Porte', 'Posti',
#                                    'age_years', 'potenza_cv']),
#                                  ('pipeline-2',
#                                   Pipeline(memory='cache',
#                                            steps=[('...
#                                            steps=[('simpleimputer',
#                                                    SimpleImputer(fill_value='Altro',
#                                                                  strategy='constant')),
#                                                   ('featurehasher',
#                                                    FeatureHasher(input_type='string',
#                                                                  n_features=256))]),
#                                   ['maker']),
#                                  ('pipeline-4',
#                                   Pipeline(memory='cache',
#                                            steps=[('simpleimputer',
#                                                    SimpleImputer(fill_value='Altro',
#                                                                  strategy='constant')),
#                                                   ('featurehasher',
#                                                    FeatureHasher(input_type='string',
#                                                                  n_features=2048))]),
#                                   ['model'])]),
#  'transformedtargetregressor__regressor__xgbregressor': XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='reg:absoluteerror', predictor=None, ...),
#  'transformedtargetregressor__regressor__columntransformer__n_jobs': None,
#  'transformedtargetregressor__regressor__columntransformer__remainder': 'drop',
#  'transformedtargetregressor__regressor__columntransformer__sparse_threshold': 0.3,
#  'transformedtargetregressor__regressor__columntransformer__transformer_weights': None,
#  'transformedtargetregressor__regressor__columntransformer__transformers': [('pipeline-1',
#    Pipeline(memory='cache',
#             steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                    ('standardscaler', StandardScaler())]),
#    ['Chilometraggio',
#     'Cilindrata_cm3',
#     'Cilindri',
#     'Consumo_comb_L100km',
#     'Marce',
#     'Peso_a_vuoto_kg',
#     'Porte',
#     'Posti',
#     'age_years',
#     'potenza_cv']),
#   ('pipeline-2',
#    Pipeline(memory='cache',
#             steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))]),
#    ['Carburante',
#     'Carrozzeria',
#     'Tipo_di_cambio',
#     'Tipo_di_veicolo',
#     'Trazione']),
#   ('pipeline-3',
#    Pipeline(memory='cache',
#             steps=[('simpleimputer',
#                     SimpleImputer(fill_value='Altro', strategy='constant')),
#                    ('featurehasher',
#                     FeatureHasher(input_type='string', n_features=256))]),
#    ['maker']),
#   ('pipeline-4',
#    Pipeline(memory='cache',
#             steps=[('simpleimputer',
#                     SimpleImputer(fill_value='Altro', strategy='constant')),
#                    ('featurehasher',
#                     FeatureHasher(input_type='string', n_features=2048))]),
#    ['model'])],
#  'transformedtargetregressor__regressor__columntransformer__verbose': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1': Pipeline(memory='cache',
#           steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                  ('standardscaler', StandardScaler())]),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2': Pipeline(memory='cache',
#           steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))]),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3': Pipeline(memory='cache',
#           steps=[('simpleimputer',
#                   SimpleImputer(fill_value='Altro', strategy='constant')),
#                  ('featurehasher',
#                   FeatureHasher(input_type='string', n_features=256))]),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4': Pipeline(memory='cache',
#           steps=[('simpleimputer',
#                   SimpleImputer(fill_value='Altro', strategy='constant')),
#                  ('featurehasher',
#                   FeatureHasher(input_type='string', n_features=2048))]),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__memory': 'cache',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__steps': [('simpleimputer',
#    SimpleImputer(strategy='median')),
#   ('standardscaler', StandardScaler())],
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__verbose': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__simpleimputer': SimpleImputer(strategy='median'),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__standardscaler': StandardScaler(),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__simpleimputer__add_indicator': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__simpleimputer__copy': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__simpleimputer__fill_value': None,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__simpleimputer__missing_values': nan,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__simpleimputer__strategy': 'median',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__simpleimputer__verbose': 0,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__standardscaler__copy': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__standardscaler__with_mean': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-1__standardscaler__with_std': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__memory': 'cache',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))],
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__verbose': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__onehotencoder': OneHotEncoder(handle_unknown='ignore'),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__simpleimputer__add_indicator': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__simpleimputer__copy': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__simpleimputer__fill_value': None,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__simpleimputer__missing_values': nan,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__simpleimputer__strategy': 'most_frequent',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__simpleimputer__verbose': 0,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__onehotencoder__categories': 'auto',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__onehotencoder__drop': None,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__onehotencoder__dtype': numpy.float64,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__onehotencoder__handle_unknown': 'ignore',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-2__onehotencoder__sparse': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__memory': 'cache',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__steps': [('simpleimputer',
#    SimpleImputer(fill_value='Altro', strategy='constant')),
#   ('featurehasher', FeatureHasher(input_type='string', n_features=256))],
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__verbose': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__simpleimputer': SimpleImputer(fill_value='Altro', strategy='constant'),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__featurehasher': FeatureHasher(input_type='string', n_features=256),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__simpleimputer__add_indicator': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__simpleimputer__copy': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__simpleimputer__fill_value': 'Altro',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__simpleimputer__missing_values': nan,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__simpleimputer__strategy': 'constant',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__simpleimputer__verbose': 0,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__featurehasher__alternate_sign': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__featurehasher__dtype': numpy.float64,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__featurehasher__input_type': 'string',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-3__featurehasher__n_features': 256,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__memory': 'cache',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__steps': [('simpleimputer',
#    SimpleImputer(fill_value='Altro', strategy='constant')),
#   ('featurehasher', FeatureHasher(input_type='string', n_features=2048))],
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__verbose': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__simpleimputer': SimpleImputer(fill_value='Altro', strategy='constant'),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__featurehasher': FeatureHasher(input_type='string', n_features=2048),
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__simpleimputer__add_indicator': False,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__simpleimputer__copy': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__simpleimputer__fill_value': 'Altro',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__simpleimputer__missing_values': nan,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__simpleimputer__strategy': 'constant',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__simpleimputer__verbose': 0,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__featurehasher__alternate_sign': True,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__featurehasher__dtype': numpy.float64,
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__featurehasher__input_type': 'string',
#  'transformedtargetregressor__regressor__columntransformer__pipeline-4__featurehasher__n_features': 2048,
#  'transformedtargetregressor__regressor__xgbregressor__objective': 'reg:absoluteerror',
#  'transformedtargetregressor__regressor__xgbregressor__base_score': None,
#  'transformedtargetregressor__regressor__xgbregressor__booster': None,
#  'transformedtargetregressor__regressor__xgbregressor__callbacks': None,
#  'transformedtargetregressor__regressor__xgbregressor__colsample_bylevel': None,
#  'transformedtargetregressor__regressor__xgbregressor__colsample_bynode': None,
#  'transformedtargetregressor__regressor__xgbregressor__colsample_bytree': None,
#  'transformedtargetregressor__regressor__xgbregressor__early_stopping_rounds': None,
#  'transformedtargetregressor__regressor__xgbregressor__enable_categorical': False,
#  'transformedtargetregressor__regressor__xgbregressor__eval_metric': None,
#  'transformedtargetregressor__regressor__xgbregressor__feature_types': None,
#  'transformedtargetregressor__regressor__xgbregressor__gamma': None,
#  'transformedtargetregressor__regressor__xgbregressor__gpu_id': None,
#  'transformedtargetregressor__regressor__xgbregressor__grow_policy': None,
#  'transformedtargetregressor__regressor__xgbregressor__importance_type': None,
#  'transformedtargetregressor__regressor__xgbregressor__interaction_constraints': None,
#  'transformedtargetregressor__regressor__xgbregressor__learning_rate': None,
#  'transformedtargetregressor__regressor__xgbregressor__max_bin': None,
#  'transformedtargetregressor__regressor__xgbregressor__max_cat_threshold': None,
#  'transformedtargetregressor__regressor__xgbregressor__max_cat_to_onehot': None,
#  'transformedtargetregressor__regressor__xgbregressor__max_delta_step': None,
#  'transformedtargetregressor__regressor__xgbregressor__max_depth': None,
#  'transformedtargetregressor__regressor__xgbregressor__max_leaves': None,
#  'transformedtargetregressor__regressor__xgbregressor__min_child_weight': None,
#  'transformedtargetregressor__regressor__xgbregressor__missing': nan,
#  'transformedtargetregressor__regressor__xgbregressor__monotone_constraints': None,
#  'transformedtargetregressor__regressor__xgbregressor__n_estimators': 100,
#  'transformedtargetregressor__regressor__xgbregressor__n_jobs': None,
#  'transformedtargetregressor__regressor__xgbregressor__num_parallel_tree': None,
#  'transformedtargetregressor__regressor__xgbregressor__predictor': None,
#  'transformedtargetregressor__regressor__xgbregressor__random_state': None,
#  'transformedtargetregressor__regressor__xgbregressor__reg_alpha': None,
#  'transformedtargetregressor__regressor__xgbregressor__reg_lambda': None,
#  'transformedtargetregressor__regressor__xgbregressor__sampling_method': None,
#  'transformedtargetregressor__regressor__xgbregressor__scale_pos_weight': None,
#  'transformedtargetregressor__regressor__xgbregressor__subsample': None,
#  'transformedtargetregressor__regressor__xgbregressor__tree_method': None,
#  'transformedtargetregressor__regressor__xgbregressor__validate_parameters': None,
#  'transformedtargetregressor__regressor__xgbregressor__verbosity': None,
#  'transformedtargetregressor__regressor': Pipeline(memory='cache',
#           steps=[('columntransformer',
#                   ColumnTransformer(transformers=[('pipeline-1',
#                                                    Pipeline(memory='cache',
#                                                             steps=[('simpleimputer',
#                                                                     SimpleImputer(strategy='median')),
#                                                                    ('standardscaler',
#                                                                     StandardScaler())]),
#                                                    ['Chilometraggio',
#                                                     'Cilindrata_cm3', 'Cilindri',
#                                                     'Consumo_comb_L100km',
#                                                     'Marce', 'Peso_a_vuoto_kg',
#                                                     'Porte', 'Posti',
#                                                     'age_years', 'potenza_c...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, n_estimators=100,
#                                n_jobs=None, num_parallel_tree=None,
#                                objective='reg:absoluteerror', predictor=None, ...))]),
#  'transformedtargetregressor__transformer': None}

# %% [markdown]
# ## Simple Pipeline Fit & Prediction

# %%
global_pipe.fit(X=X_train, y=y_train)
# Out:
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 1.00s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 2.60s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# Pipeline(memory='cache',
#          steps=[('transformedtargetregressor',
#                  TransformedTargetRegressor(func=<ufunc 'log'>,
#                                             inverse_func=<ufunc 'exp'>,
#                                             regressor=Pipeline(memory='cache',
#                                                                steps=[('columntransformer',
#                                                                        ColumnTransformer(transformers=[('pipeline-1',
#                                                                                                         Pipeline(memory='cache',
#                                                                                                                  steps=[('simpleimputer',
#                                                                                                                          SimpleImputer(strategy='median')),
#                                                                                                                         ('standardscaler',
#                                                                                                                          StandardSc...
#                                                                                     grow_policy=None,
#                                                                                     importance_type=None,
#                                                                                     interaction_constraints=None,
#                                                                                     learning_rate=None,
#                                                                                     max_bin=None,
#                                                                                     max_cat_threshold=None,
#                                                                                     max_cat_to_onehot=None,
#                                                                                     max_delta_step=None,
#                                                                                     max_depth=None,
#                                                                                     max_leaves=None,
#                                                                                     min_child_weight=None,
#                                                                                     missing=nan,
#                                                                                     monotone_constraints=None,
#                                                                                     n_estimators=100,
#                                                                                     n_jobs=None,
#                                                                                     num_parallel_tree=None,
#                                                                                     objective='reg:absoluteerror',
#                                                                                     predictor=None, ...))])))])

# %%
y_pred_train = global_pipe.predict(X=X_train)
y_pred_test = global_pipe.predict(X=X_test)

# %%
print('Train metrics')
print(f'R2: {global_pipe.score(X=X_train, y=y_train)}')
print(f'MAE: {mean_absolute_error(y_train, y_pred_train)}')
print('Test metrics')
print(f'R2: {global_pipe.score(X=X_test, y=y_test)}')
print(f'MAE: {mean_absolute_error(y_test, y_pred_test)}')
# Out:
# Train metrics
# R2: 0.7798331869616257
# MAE: 3111.0865540754107
# Test metrics
# R2: 0.7817911822381012
# MAE: 3411.942328975438

# %% [markdown]
# ## Cross Validation

# %%
param_grid = dict(
    transformedtargetregressor__regressor__xgbregressor__n_estimators=[150],
    transformedtargetregressor__regressor__xgbregressor__eta=[0.1],
    transformedtargetregressor__regressor__xgbregressor__max_depth=[6],
    transformedtargetregressor__regressor__xgbregressor__gamma=[0.0, 0.1, 0.3],
    transformedtargetregressor__regressor__xgbregressor__reg_lambda=[1, 1.2, 1.5]
)
#transformedtargetregressor__regressor__xgbregressor__

grid_search = GridSearchCV(
    global_pipe, 
    param_grid=param_grid,
    scoring=['neg_mean_absolute_error', 'r2'],
    cv=5,
    refit='neg_mean_absolute_error'
    )

# %%
grid_search.fit(X_train, y_train)
# Out:
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 0.78s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 2.03s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# COMET WARNING: XGBoost callback couldn't be injected
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 0.86s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 2.24s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# COMET WARNING: XGBoost callback couldn't be injected
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 0.83s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 2.19s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# COMET WARNING: XGBoost callback couldn't be injected
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 0.84s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 2.21s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# COMET WARNING: XGBoost callback couldn't be injected
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 0.84s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# c:\Users\bestengage\anaconda3\lib\site-packages\sklearn\pipeline.py:303: UserWarning: Persisting input arguments took 2.19s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, fitted_transformer = fit_transform_one_cached(
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# COMET WARNING: XGBoost callback couldn't be injected
# GridSearchCV(cv=5,
#              estimator=Pipeline(memory='cache',
#                                 steps=[('transformedtargetregressor',
#                                         TransformedTargetRegressor(func=<ufunc 'log'>,
#                                                                    inverse_func=<ufunc 'exp'>,
#                                                                    regressor=Pipeline(memory='cache',
#                                                                                       steps=[('columntransformer',
#                                                                                               ColumnTransformer(transformers=[('pipeline-1',
#                                                                                                                                Pipeline(memory='cache',
#                                                                                                                                         steps=[('simpleimputer',
#                                                                                                                                                 SimpleImputer(strategy='median')),...
#                          'transformedtargetregressor__regressor__xgbregressor__gamma': [0.0,
#                                                                                         0.1,
#                                                                                         0.3],
#                          'transformedtargetregressor__regressor__xgbregressor__max_depth': [6],
#                          'transformedtargetregressor__regressor__xgbregressor__n_estimators': [150],
#                          'transformedtargetregressor__regressor__xgbregressor__reg_lambda': [1,
#                                                                                              1.2,
#                                                                                              1.5]},
#              refit='neg_mean_absolute_error',
#              scoring=['neg_mean_absolute_error', 'r2'])

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(pd.DataFrame.from_dict(grid_search.cv_results_).sort_values(by='rank_test_neg_mean_absolute_error'))
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6      12.768128      0.094771         0.181971        0.002466
# 4      12.694197      0.258038         0.180798        0.003322
# 3      12.831336      0.273034         0.183466        0.005655
# 8      12.870464      0.290376         0.183389        0.003496
# 7      12.728187      0.088751         0.183191        0.000847
# 2      12.666907      0.098966         0.184476        0.004265
# 1      12.607214      0.113320         0.181425        0.001034
# 0      21.235334      2.169251         0.171050        0.026705
# 5      13.021984      0.711174         0.183980        0.003914
#
#   param_transformedtargetregressor__regressor__xgbregressor__eta  \
# 6                                                0.1
# 4                                                0.1
# 3                                                0.1
# 8                                                0.1
# 7                                                0.1
# 2                                                0.1
# 1                                                0.1
# 0                                                0.1
# 5                                                0.1
#
#   param_transformedtargetregressor__regressor__xgbregressor__gamma  \
# 6                                                0.3
# 4                                                0.1
# 3                                                0.1
# 8                                                0.3
# 7                                                0.3
# 2                                                0.0
# 1                                                0.0
# 0                                                0.0
# 5                                                0.1
#
#   param_transformedtargetregressor__regressor__xgbregressor__max_depth  \
# 6                                                  6
# 4                                                  6
# 3                                                  6
# 8                                                  6
# 7                                                  6
# 2                                                  6
# 1                                                  6
# 0                                                  6
# 5                                                  6
#
#   param_transformedtargetregressor__regressor__xgbregressor__n_estimators  \
# 6                                                150
# 4                                                150
# 3                                                150
# 8                                                150
# 7                                                150
# 2                                                150
# 1                                                150
# 0                                                150
# 5                                                150
#
#   param_transformedtargetregressor__regressor__xgbregressor__reg_lambda  \
# 6                                                  1
# 4                                                1.2
# 3                                                  1
# 8                                                1.5
# 7                                                1.2
# 2                                                1.5
# 1                                                1.2
# 0                                                  1
# 5                                                1.5
#
#                                               params  \
# 6  {'transformedtargetregressor__regressor__xgbre...
# 4  {'transformedtargetregressor__regressor__xgbre...
# 3  {'transformedtargetregressor__regressor__xgbre...
# 8  {'transformedtargetregressor__regressor__xgbre...
# 7  {'transformedtargetregressor__regressor__xgbre...
# 2  {'transformedtargetregressor__regressor__xgbre...
# 1  {'transformedtargetregressor__regressor__xgbre...
# 0  {'transformedtargetregressor__regressor__xgbre...
# 5  {'transformedtargetregressor__regressor__xgbre...
#
#    split0_test_neg_mean_absolute_error  split1_test_neg_mean_absolute_error  \
# 6                         -2440.592189                         -2337.222750
# 4                         -2474.302593                         -2316.941568
# 3                         -2411.451745                         -2362.330800
# 8                         -2454.346545                         -2315.308670
# 7                         -2486.369463                         -2333.389007
# 2                         -2478.489597                         -2335.897709
# 1                         -2506.387692                         -2306.702899
# 0                         -2488.613981                         -2357.727004
# 5                         -2506.262810                         -2333.034173
#
#    split2_test_neg_mean_absolute_error  split3_test_neg_mean_absolute_error  \
# 6                         -2229.276578                         -2381.495652
# 4                         -2235.972534                         -2390.369824
# 3                         -2265.251604                         -2360.942761
# 8                         -2237.310719                         -2413.701692
# 7                         -2228.275835                         -2400.428132
# 2                         -2247.673239                         -2320.472418
# 1                         -2222.365581                         -2392.313544
# 0                         -2254.293450                         -2366.100920
# 5                         -2277.323688                         -2372.125429
#
#    split4_test_neg_mean_absolute_error  mean_test_neg_mean_absolute_error  \
# 6                         -2507.280992                       -2379.173632
# 4                         -2481.549910                       -2379.827286
# 3                         -2523.715931                       -2384.738568
# 8                         -2525.549786                       -2389.243482
# 7                         -2518.417999                       -2393.376087
# 2                         -2586.462593                       -2393.799111
# 1                         -2551.354546                       -2395.824852
# 0                         -2516.427127                       -2396.632496
# 5                         -2503.164557                       -2398.382131
#
#    std_test_neg_mean_absolute_error  rank_test_neg_mean_absolute_error  \
# 6                         94.252989                                  1
# 4                         93.843513                                  2
# 3                         84.111574                                  3
# 8                        101.946988                                  4
# 7                        105.061432                                  5
# 2                        121.962160                                  6
# 1                        122.030158                                  7
# 0                         95.412332                                  8
# 5                         91.904858                                  9
#
#    split0_test_r2  split1_test_r2  split2_test_r2  split3_test_r2  \
# 6        0.801677        0.888676        0.892251        0.833681
# 4        0.806489        0.893879        0.891843        0.832570
# 3        0.791547        0.849321        0.889686        0.836803
# 8        0.788859        0.885729        0.885002        0.818950
# 7        0.792958        0.893177        0.902016        0.831597
# 2        0.788617        0.896104        0.890360        0.834849
# 1        0.795679        0.894893        0.899714        0.832494
# 0        0.783922        0.884652        0.887253        0.828055
# 5        0.782731        0.874368        0.888822        0.833261
#
#    split4_test_r2  mean_test_r2  std_test_r2  rank_test_r2
# 6        0.696159      0.822489     0.071785             1
# 4        0.674329      0.819822     0.080225             3
# 3        0.697751      0.813022     0.065589             8
# 8        0.686084      0.812925     0.073756             9
# 7        0.683449      0.820639     0.079488             2
# 2        0.681753      0.818337     0.078799             5
# 1        0.671341      0.818824     0.083431             4
# 0        0.692429      0.815262     0.072431             6
# 5        0.692622      0.814361     0.071167             7

# %% [markdown]
# ## Comet Tracking

# %%
load_dotenv()
COMET_API_KEY = os.environ.get('COMET_API_KEY')
COMET_PROJECT_NAME = os.environ.get('COMET_PROJECT_NAME')
COMET_WORKSPACE = os.environ.get('COMET_WORKSPACE')

# %%
pipeline_params = {"model_type":"xgb",
                    "transform_target":True
    }

# %%
for i in range(len(grid_search.cv_results_['params'])):
    exp = Experiment(api_key=COMET_API_KEY,
                        project_name=COMET_PROJECT_NAME,
                        workspace=COMET_WORKSPACE,
                        auto_param_logging=False
                    )

    exp.log_parameters(pipeline_params)

    for k,v in grid_search.cv_results_.items():
        if k == "params":
            exp.log_parameters(v[i])
        else:
            exp.log_metric(k,v[i])
    
    exp.end()
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/aafe855437944a518eb0ee1f90f0dfe5
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/aafe855437944a518eb0ee1f90f0dfe5
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 21.235334157943726
# COMET INFO:     mean_score_time                                                         : 0.1710495948791504
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2396.6324963660436
# COMET INFO:     mean_test_r2                                                            : 0.8152620735206522
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.0
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 8
# COMET INFO:     rank_test_r2                                                            : 6
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2488.613981057058
# COMET INFO:     split0_test_r2                                                          : 0.7839217179414917
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2357.7270038111083
# COMET INFO:     split1_test_r2                                                          : 0.8846515495848423
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2254.293449903641
# COMET INFO:     split2_test_r2                                                          : 0.8872530871225185
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2366.100919751199
# COMET INFO:     split3_test_r2                                                          : 0.8280554605491496
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2516.427127307212
# COMET INFO:     split4_test_r2                                                          : 0.6924285524052591
# COMET INFO:     std_fit_time                                                            : 2.1692513345304594
# COMET INFO:     std_score_time                                                          : 0.02670515323447269
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 95.41233232412914
# COMET INFO:     std_test_r2                                                             : 0.07243144065525932
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.0
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: All files uploaded, waiting for confirmation they have been all received
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/444aa453876d4bafa46fd8c957f4bd6f
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/444aa453876d4bafa46fd8c957f4bd6f
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 12.607214164733886
# COMET INFO:     mean_score_time                                                         : 0.18142457008361818
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2395.8248522162116
# COMET INFO:     mean_test_r2                                                            : 0.8188241619348103
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.0
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.2
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 7
# COMET INFO:     rank_test_r2                                                            : 4
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2506.387691858813
# COMET INFO:     split0_test_r2                                                          : 0.7956793320762527
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2306.7028988686
# COMET INFO:     split1_test_r2                                                          : 0.8948928555099864
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2222.3655811051412
# COMET INFO:     split2_test_r2                                                          : 0.89971354814889
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2392.31354369967
# COMET INFO:     split3_test_r2                                                          : 0.8324942271222598
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2551.3545455488356
# COMET INFO:     split4_test_r2                                                          : 0.6713408468166621
# COMET INFO:     std_fit_time                                                            : 0.11331966684511532
# COMET INFO:     std_score_time                                                          : 0.001033616309880527
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 122.03015824651843
# COMET INFO:     std_test_r2                                                             : 0.08343071498432014
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.0
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.2
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: All files uploaded, waiting for confirmation they have been all received
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/17eda6ff7cfe42838a22ffd3c0d1e849
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/17eda6ff7cfe42838a22ffd3c0d1e849
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 12.666907215118409
# COMET INFO:     mean_score_time                                                         : 0.18447561264038087
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2393.799111152351
# COMET INFO:     mean_test_r2                                                            : 0.8183365719698568
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.0
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.5
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 6
# COMET INFO:     rank_test_r2                                                            : 5
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2478.489596894477
# COMET INFO:     split0_test_r2                                                          : 0.7886169313675722
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2335.8977093126455
# COMET INFO:     split1_test_r2                                                          : 0.8961036213413521
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2247.67323895605
# COMET INFO:     split2_test_r2                                                          : 0.8903598072391355
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2320.4724175155893
# COMET INFO:     split3_test_r2                                                          : 0.8348494308429479
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2586.4625930829934
# COMET INFO:     split4_test_r2                                                          : 0.6817530690582756
# COMET INFO:     std_fit_time                                                            : 0.09896637858853106
# COMET INFO:     std_score_time                                                          : 0.004264915306931253
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 121.96216011920124
# COMET INFO:     std_test_r2                                                             : 0.078798534504002
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.0
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.5
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 1 file(s), remaining 10.93 KB/198.29 KB
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/1360729d4f234473bdf2e510ded35e99
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/1360729d4f234473bdf2e510ded35e99
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 12.831336164474488
# COMET INFO:     mean_score_time                                                         : 0.18346567153930665
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2384.7385682203617
# COMET INFO:     mean_test_r2                                                            : 0.8130218237831752
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 3
# COMET INFO:     rank_test_r2                                                            : 8
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2411.4517453672142
# COMET INFO:     split0_test_r2                                                          : 0.7915471956857905
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2362.3307996152053
# COMET INFO:     split1_test_r2                                                          : 0.8493214084709384
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2265.2516037820697
# COMET INFO:     split2_test_r2                                                          : 0.8896864715204293
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2360.9427609771774
# COMET INFO:     split3_test_r2                                                          : 0.8368034265017008
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2523.715931360143
# COMET INFO:     split4_test_r2                                                          : 0.6977506167370167
# COMET INFO:     std_fit_time                                                            : 0.27303406833872296
# COMET INFO:     std_score_time                                                          : 0.005655290011812671
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 84.11157412087874
# COMET INFO:     std_test_r2                                                             : 0.0655885714356434
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 1 file(s), remaining 26.93 KB/198.29 KB
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/bc4d1dca38b1447dbd636f5f51cfd677
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/bc4d1dca38b1447dbd636f5f51cfd677
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 12.694197416305542
# COMET INFO:     mean_score_time                                                         : 0.18079824447631837
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2379.827285759014
# COMET INFO:     mean_test_r2                                                            : 0.8198219121175949
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.2
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 2
# COMET INFO:     rank_test_r2                                                            : 3
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2474.302592843913
# COMET INFO:     split0_test_r2                                                          : 0.8064892368285019
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2316.9415683730695
# COMET INFO:     split1_test_r2                                                          : 0.8938788758777213
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2235.97253363911
# COMET INFO:     split2_test_r2                                                          : 0.8918425302150694
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2390.3698237502113
# COMET INFO:     split3_test_r2                                                          : 0.8325703317337307
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2481.549910188767
# COMET INFO:     split4_test_r2                                                          : 0.674328585932951
# COMET INFO:     std_fit_time                                                            : 0.2580376325023826
# COMET INFO:     std_score_time                                                          : 0.0033217495142287205
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 93.84351254677358
# COMET INFO:     std_test_r2                                                             : 0.08022467663986638
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.2
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 1 file(s), remaining 42.93 KB/198.29 KB
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/096827e2b1e247e9a6e4ec2f5ab0ba52
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/096827e2b1e247e9a6e4ec2f5ab0ba52
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 13.021984481811524
# COMET INFO:     mean_score_time                                                         : 0.18397979736328124
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2398.3821312999276
# COMET INFO:     mean_test_r2                                                            : 0.814360846246194
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.5
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 9
# COMET INFO:     rank_test_r2                                                            : 7
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2506.262809694605
# COMET INFO:     split0_test_r2                                                          : 0.7827313942401808
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2333.0341731905646
# COMET INFO:     split1_test_r2                                                          : 0.874368269342749
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2277.3236881235457
# COMET INFO:     split2_test_r2                                                          : 0.8888220533308311
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2372.1254286326875
# COMET INFO:     split3_test_r2                                                          : 0.833260814964708
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2503.1645568582353
# COMET INFO:     split4_test_r2                                                          : 0.6926216993525005
# COMET INFO:     std_fit_time                                                            : 0.7111740033802209
# COMET INFO:     std_score_time                                                          : 0.003913854740438834
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 91.9048575485391
# COMET INFO:     std_test_r2                                                             : 0.07116658362652512
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.5
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: All files uploaded, waiting for confirmation they have been all received
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/826942d881954091a3a6834229d370fd
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/826942d881954091a3a6834229d370fd
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 12.768127727508546
# COMET INFO:     mean_score_time                                                         : 0.18197083473205566
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2379.1736320482114
# COMET INFO:     mean_test_r2                                                            : 0.8224887380656808
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.3
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 1
# COMET INFO:     rank_test_r2                                                            : 1
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2440.5921890236264
# COMET INFO:     split0_test_r2                                                          : 0.8016767872663515
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2337.222749809877
# COMET INFO:     split1_test_r2                                                          : 0.8886758144276092
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2229.276577882421
# COMET INFO:     split2_test_r2                                                          : 0.8922510031648235
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2381.4956519221455
# COMET INFO:     split3_test_r2                                                          : 0.8336810190637088
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2507.2809916029883
# COMET INFO:     split4_test_r2                                                          : 0.6961590664059113
# COMET INFO:     std_fit_time                                                            : 0.09477080845296258
# COMET INFO:     std_score_time                                                          : 0.0024660305915608013
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 94.25298919131492
# COMET INFO:     std_test_r2                                                             : 0.0717845291142604
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.3
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 1 file(s), remaining 114.93 KB/198.29 KB
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/fb6204d3a64c42d4bc6030e2e620f5ce
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/fb6204d3a64c42d4bc6030e2e620f5ce
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 12.728186702728271
# COMET INFO:     mean_score_time                                                         : 0.18319120407104492
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2393.3760873738015
# COMET INFO:     mean_test_r2                                                            : 0.8206392026905525
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.3
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.2
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 5
# COMET INFO:     rank_test_r2                                                            : 2
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2486.3694634896647
# COMET INFO:     split0_test_r2                                                          : 0.7929575409722223
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2333.389007273044
# COMET INFO:     split1_test_r2                                                          : 0.8931770306797144
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2228.275835239635
# COMET INFO:     split2_test_r2                                                          : 0.9020157323003585
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2400.4281321822555
# COMET INFO:     split3_test_r2                                                          : 0.8315969417793846
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2518.417998684408
# COMET INFO:     split4_test_r2                                                          : 0.6834487677210823
# COMET INFO:     std_fit_time                                                            : 0.08875109977408875
# COMET INFO:     std_score_time                                                          : 0.0008473800623772744
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 105.06143151070846
# COMET INFO:     std_test_r2                                                             : 0.07948765683961288
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.3
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.2
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 1 file(s), remaining 10.93 KB/198.29 KB
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cusano-a/used-cars-prices/764eb9dd8f9848fca3f880d73bfc2f29
#
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/cusano-a/used-cars-prices/764eb9dd8f9848fca3f880d73bfc2f29
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                                                           : 12.87046413421631
# COMET INFO:     mean_score_time                                                         : 0.18338899612426757
# COMET INFO:     mean_test_neg_mean_absolute_error                                       : -2389.2434823725134
# COMET INFO:     mean_test_r2                                                            : 0.8129249546489294
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__gamma        : 0.3
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     param_transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.5
# COMET INFO:     rank_test_neg_mean_absolute_error                                       : 4
# COMET INFO:     rank_test_r2                                                            : 9
# COMET INFO:     split0_test_neg_mean_absolute_error                                     : -2454.3465445632523
# COMET INFO:     split0_test_r2                                                          : 0.7888589687897297
# COMET INFO:     split1_test_neg_mean_absolute_error                                     : -2315.3086702416563
# COMET INFO:     split1_test_r2                                                          : 0.8857294474764993
# COMET INFO:     split2_test_neg_mean_absolute_error                                     : -2237.3107193491196
# COMET INFO:     split2_test_r2                                                          : 0.8850023501202517
# COMET INFO:     split3_test_neg_mean_absolute_error                                     : -2413.70169163243
# COMET INFO:     split3_test_r2                                                          : 0.8189503711976018
# COMET INFO:     split4_test_neg_mean_absolute_error                                     : -2525.5497860761075
# COMET INFO:     split4_test_r2                                                          : 0.6860836356605646
# COMET INFO:     std_fit_time                                                            : 0.29037580037860167
# COMET INFO:     std_score_time                                                          : 0.0034962733259205373
# COMET INFO:     std_test_neg_mean_absolute_error                                        : 101.946988244771
# COMET INFO:     std_test_r2                                                             : 0.07375614230215324
# COMET INFO:   Parameters:
# COMET INFO:     model_type                                                        : xgb
# COMET INFO:     transform_target                                                  : True
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__eta          : 0.1
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__gamma        : 0.3
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__max_depth    : 6
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__n_estimators : 150
# COMET INFO:     transformedtargetregressor__regressor__xgbregressor__reg_lambda   : 1.5
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (134.15 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 1 file(s), remaining 34.93 KB/198.29 KB

# %% [markdown]
# ## Best Model Save

# %%
grid_search.best_params_
# Out:
# {'transformedtargetregressor__regressor__xgbregressor__eta': 0.1,
#  'transformedtargetregressor__regressor__xgbregressor__gamma': 0.3,
#  'transformedtargetregressor__regressor__xgbregressor__max_depth': 6,
#  'transformedtargetregressor__regressor__xgbregressor__n_estimators': 150,
#  'transformedtargetregressor__regressor__xgbregressor__reg_lambda': 1}

# %%
out_model_file_name = 'XGB_'+re.sub("[.,:,-, ]","_",str(datetime.now()))+'.pkl'
joblib.dump(grid_search.best_estimator_, os.path.join("models", out_model_file_name))
# Out:
# ['models\\XGB_2023-02-22_17_02_28_020471.pkl']
